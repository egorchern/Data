# %% [markdown]
# <h1>Classification of Degrees awarded (2017/18)</h1>
# <p>In this Notebook you will show the degree classifications awareded from academic year 2017/18 as a bar plot</p>
# <p>You will require the files produced when you completed the previous exercise</p>

# %% [markdown]
# <h2>Import PANDAs and Matplotlib.pylot</h2>
# <p>You will be using the pandas dataframe to store the data and Matplotlib pyplot to plot the data.  Import the necessary libraries</h2>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# <h2>Read the data into a PANDAs DataFrame</h2>
# <p>Read the 'df.csv' in to a data frame called df, use the head method to output the first 20 rows of the datafile so that the structure of the dataframe can be explored.</p>

# %%
df = pd.read_csv("df.csv")
df.head(20)
# Out:
#     Unnamed: 0 Academic Year Classification of First Degree  Number  \
# 0           95       2013/14                          First   73810
# 1           96       2013/14                   Lower second   85760
# 2           97       2013/14                     Third/Pass   16670
# 3           99       2013/14                   Upper second  186125
# 4          370       2014/15                          First   76030
# 5          371       2014/15                   Lower second   75350
# 6          372       2014/15                     Third/Pass   15080
# 7          374       2014/15                   Upper second  171705
# 8          645       2015/16                          First   83720
# 9          646       2015/16                   Lower second   73180
# 10         647       2015/16                     Third/Pass   14335
# 11         649       2015/16                   Upper second  176215
# 12         920       2016/17                          First   95525
# 13         921       2016/17                   Lower second   71290
# 14         922       2016/17                     Third/Pass   14225
# 15         924       2016/17                   Upper second  182305
# 16        1200       2017/18                          First  105500
# 17        1201       2017/18                   Lower second   69105
# 18        1202       2017/18                     Third/Pass   13435
# 19        1204       2017/18                   Upper second  184150
#
#     Percentage
# 0           20
# 1           24
# 2            5
# 3           51
# 4           22
# 5           22
# 6            4
# 7           51
# 8           24
# 9           21
# 10           4
# 11          51
# 12          26
# 13          20
# 14           4
# 15          50
# 16          28
# 17          19
# 18           4
# 19          49

# %% [markdown]
# <h2>Creating a new DataFrame</h2>
# <p>Create a new dataframe named df_17_18 that contains only the rows where the 'Academic Year' column has the value '2017/18', then output the dataframe to make sure you have the correct four rows.</p>

# %%
df_17_18 = df[df["Academic Year"] == "2017/18"]
df_17_18.head()
# Out:
#     Unnamed: 0 Academic Year Classification of First Degree  Number  \
# 16        1200       2017/18                          First  105500
# 17        1201       2017/18                   Lower second   69105
# 18        1202       2017/18                     Third/Pass   13435
# 19        1204       2017/18                   Upper second  184150
#
#     Percentage
# 16          28
# 17          19
# 18           4
# 19          49

# %% [markdown]
# <h2>Setting the Index</h2>
# <p>Set Academic Year as the row index and remove any unnamed columns.  Then output the dataframe to make sure it is as expected</p>

# %%
df_17_18.set_index("Academic Year")
df_17_18 = df_17_18.drop(["Unnamed: 0"], axis=1)
df_17_18.head()
# Out:
#    Academic Year Classification of First Degree  Number  Percentage
# 16       2017/18                          First  105500          28
# 17       2017/18                   Lower second   69105          19
# 18       2017/18                     Third/Pass   13435           4
# 19       2017/18                   Upper second  184150          49

# %% [markdown]
# <h2>Define the Size of the Figure</h2>
# <p>We are now ready to plot.  Figures consist of one or more plots, set the size of the figure to 10 inches by 5 inches. Give your figure a name called '17_18' and assign this object to a variable named fig</p>

# %%
fig = plt.figure(figsize =(10, 5))

# %% [markdown]
# <h2>Create a Plot</h2>
# <p>Create a bar plot using using the data from the 'Classification of First Degree' and 'Percentage' columns.  Give the plot a label equal to 'Degrees 2017/18'.</p>

# %%
fig, ax = plt.subplots(figsize =(10, 5))
fig.set_dpi(100)
plt.bar(df_17_18["Classification of First Degree"], df_17_18["Percentage"], width=0.5)
plt.xlabel("Classification of First Degree")
plt.ylabel("Percentage of total awarded")
plt.title("Percentages of classifications of First degrees awarded")
plt.show()

# %%
fig, ax = plt.subplots(figsize =(10, 5))
fig.set_dpi(100)
# Horizontal Bar Plot
ax.barh(df_17_18["Classification of First Degree"], df_17_18["Percentage"], height=0.4)
# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
    ax.spines[s].set_visible(False)
 
# Remove x, y Ticks
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
 
# Add padding between axes and labels
ax.xaxis.set_tick_params(pad = 5)
ax.yaxis.set_tick_params(pad = 10)
# Add x, y gridlines
ax.grid(color ='grey',
        linestyle ='-.', linewidth = 1,
        alpha = 0.2)
# Show top values
ax.invert_yaxis()
 
# Add annotation to bars
for i in ax.patches:
    plt.text(i.get_width()+0.1, i.get_y() + 0.25,
             str(round((i.get_width()), 2)),
             fontsize = 10, fontweight ='bold',
             color ='grey')
ax.set_title("Percentages of classifications of First degrees awarded")
plt.show()

# %% [markdown]
# <h2>Resetting and Reording the Index</h2>
# <p>Reset the index (so things are easier to shuffle around), then, reorder the index so that the classifications are in order from First to Third.</p>
# <p>Replot to check things worked as expected.</p>

# %%
df_17_18.reset_index(inplace = True)
df_17_18.drop(["index"], axis=1, inplace = True)
temp = df_17_18.iloc[3]
df_17_18.iloc[3] = df_17_18.iloc[2]
df_17_18.iloc[2] = temp
temp = df_17_18.iloc[2]
df_17_18.iloc[2] = df_17_18.iloc[1]
df_17_18.iloc[1] = temp
fig, ax = plt.subplots(figsize =(10, 5))
fig.set_dpi(100)
plt.bar(df_17_18["Classification of First Degree"], df_17_18["Percentage"], width=0.5)

plt.title("Percentages of classifications of First degrees awarded")
# Out:
# Text(0.5, 1.0, 'Percentages of classifications of First degrees awarded')

# %% [markdown]
# <h2>Adding x and y labels</h2>
# <p>Add a x label 'Classification of First Degree' and a y label '% Achieved', then replot</p>

# %%
fig, ax = plt.subplots(figsize =(10, 5))
fig.set_dpi(100)
plt.bar(df_17_18["Classification of First Degree"], df_17_18["Percentage"], width=0.5)
plt.xlabel("Classification of First Degree")
plt.ylabel("Percentage of total awarded")
plt.title("Percentages of classifications of First degrees awarded")
plt.show()

# %% [markdown]
# <h2>Add a Title to the Plot</h2>
# <p>Add a title to the plot, 'Percentage of First Class Degrees Awarded'</p>

# %% [markdown]
# <h2>Horizontal Bar Plots</h2>
# <p>Change the plot so that a horizontal bar graph is plotted.</p>

# %%
fig, ax = plt.subplots(figsize =(10, 5))
fig.set_dpi(100)
# Horizontal Bar Plot
ax.barh(df_17_18["Classification of First Degree"], df_17_18["Percentage"], height=0.4)
# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
    ax.spines[s].set_visible(False)
 
# Remove x, y Ticks
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
 
# Add padding between axes and labels
ax.xaxis.set_tick_params(pad = 5)
ax.yaxis.set_tick_params(pad = 10)
# Add x, y gridlines
ax.grid(color ='grey',
        linestyle ='-.', linewidth = 1,
        alpha = 0.2)
# Show top values
ax.invert_yaxis()
 
# Add annotation to bars
for i in ax.patches:
    plt.text(i.get_width()+0.1, i.get_y() + 0.25,
             str(round((i.get_width()), 2)),
             fontsize = 10, fontweight ='bold',
             color ='black')
ax.set_title("Percentages of classifications of First degrees awarded")
plt.show()

# %% [markdown]
# <h2>What the Plot tells you</h2>
# <p>Based on your plot, complete the following statements</p>
# <ul>
# <li>The most common degree classification awarded for academic year 2017/18 was a Upper second</li>
# <li>The least common degree classification awarded for academic year 2017/18 was a Third/Pass</li>
# <li>Approximately 30% of degrees awarded for academic year 2017/18 were First class degrees.</li>
# <li>Approximately 20% of degrees awarded for academic year 2017/18 were Lower second class degrees.</li>
# </ul>
